# %% [markdown]
# <a href="https://colab.research.google.com/github/AlicePF43/Amigo-Secreto/blob/main/alunos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url= "https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv"

# %%
df = pd.read_csv(url)

# %%
print(df.head())
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True

# %%
df.isnull()
# Out:
#      Nome  Idade  Notas  Aprovado
# 0   False  False  False     False
# 1   False  False   True     False
# 2   False  False  False     False
# 3   False  False  False     False
# 4   False  False  False     False
# 5   False  False   True     False
# 6   False  False  False     False
# 7   False  False  False     False
# 8   False  False  False     False
# 9   False  False   True     False
# 10  False  False   True     False
# 11  False  False  False     False
# 12  False  False  False     False
# 13  False  False  False     False
# 14  False  False   True     False
# 15  False  False  False     False
# 16  False  False   True     False
# 17  False  False  False     False

# %%
df.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       0
# Aprovado    0
# dtype: int64

# %%
df.query("Nome == 'Alice' | Nome == 'Carlos'")
# Out:
#      Nome  Idade  Notas  Aprovado
# 7  Carlos     19    6.0      True
# 8   Alice     35    5.6     False

# %%
# 2️ Pegando os índices dessas linhas
registros_a_remover = df.query("Nome == 'Alice' | Nome == 'Carlos'").index

# %%
# Remover Alice e Carlos
df.drop(df.query("Nome == 'Alice' | Nome == 'Carlos'").index, axis=0, inplace=True)

# %%
# Verificar se ainda existem na base
print(df.query("Nome == 'Alice' | Nome == 'Carlos'"))
# Out:
# Empty DataFrame
# Columns: [Nome, Idade, Notas, Aprovado]
# Index: []

# %%
df[df["Aprovado"] == True]
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
df["Notas"] = df["Notas"].replace(7.0, 8.0)

# %%
print((df["Notas"] == 7.0).sum())  # Conta quantas notas 7.0 ainda existem
# Out:
# 0

# %%
df.to_csv("alunos_aprovados.csv", index=False, sep=";")

# %%
df_check = pd.read_csv("alunos_aprovados.csv", sep=";")

# %%
print(df_check.head())  # Verifica as primeiras linhas do arquivo
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    0.0     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
